# %%
import option_language
import importlib
importlib.reload(option_language)
# Out:
# <module 'option_language' from '/Users/guozhewen/Documents/GitHub/AI_TRPG_616/Code/user_info/option_language.py'>

# %%
user_language = option_language.Option_Language.CHINESE_SIMPLIFIED

# %%
user_language.value
# Out:
# 1

# %%
user_language.system_prompt()
# Out:
# 'Reply strictly in 中文（简体） (zh-CN).'
